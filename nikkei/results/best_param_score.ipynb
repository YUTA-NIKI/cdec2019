# %%
import pandas as pd

# %% [markdown]
# # the latest gridsearch results calculated by hpc11

# %%
pd.read_csv('gridsearch_lstm_att_w2v.csv').sort_values('f1', ascending=False).head(5)
# Out:
#                        word2vec  epoch  batch_size  hidden_dim activate_func  \
# 1974  w2v_jawiki_d400_w12.model    200          64         200          relu
# 1975  w2v_jawiki_d400_w12.model    300          64         200          relu
# 1976  w2v_jawiki_d400_w12.model    400          64         200          relu
# 1952  w2v_jawiki_d400_w12.model    400          64         200          tanh
# 1928  w2v_jawiki_d400_w12.model    400          64         200          relu
#
#      optimizer  learning_rate  l2_regular  dropout_rate  accuracy  precision  \
# 1974      adam          0.001         0.0           0.5  0.878244   0.859155
# 1975      adam          0.001         0.0           0.5  0.876248   0.858491
# 1976      adam          0.001         0.0           0.5  0.872255   0.847222
# 1952      adam          0.001         0.0           0.5  0.866267   0.832579
# 1928      adam          0.001         0.0           0.0  0.866267   0.835616
#
#         recall        f1       auc
# ...

# %%
pd.read_csv('gridsearch_lstm_w2v.csv').sort_values('f1', ascending=False).head(5)
# Out:
#                        word2vec  epoch  batch_size  hidden_dim activate_func  \
# 213   w2v_jawiki_d200_w12.model    200          64         200          tanh
# 338   w2v_jawiki_d200_w12.model    400          64         300          relu
# 1921  w2v_jawiki_d400_w12.model    300          64         200          relu
# 597   w2v_jawiki_d200_w12.model    200         128         300          tanh
# 87    w2v_jawiki_d200_w12.model    200          64         100          tanh
#
#      optimizer  learning_rate  l2_regular  dropout_rate  accuracy  precision  \
# 213       adam          0.001       0.000           0.5  0.858283   0.820628
# 338       adam          0.001       0.001           0.5  0.846307   0.784232
# 1921      adam          0.001       0.001           0.0  0.852295   0.818182
# 597       adam          0.001       0.000           0.5  0.850299   0.811659
# 87        adam          0.001       0.001           0.5  0.850299   0.817352
#
#         recall        f1       auc
# ...

# %% [markdown]
# # the latest gridsearch results calculated by sparrow

# %%
pd.read_csv('gridsearch_lstm_attention_end2end.csv').sort_values('f1', ascending=False).head(5)
# Out:
#      epoch  batch_size  embedding_dim  hidden_dim activate_func optimizer  \
# 484    300         128            200         100          relu      adam
# 213    200          64            200         300          tanh      adam
# 214    300          64            200         300          tanh      adam
# 595    200         128            200         300          tanh      adam
# 297    200          64            300         100          relu       sgd
#
#      learning_rate  l2_regular  dropout_rate  accuracy  precision    recall  \
# 484          0.100       0.001           0.0  0.858283   0.845411  0.817757
# 213          0.001       0.000           0.0  0.852295   0.857143  0.785047
# 214          0.001       0.000           0.0  0.852295   0.868421  0.771028
# 595          0.100       0.001           0.0  0.832335   0.795455  0.817757
# 297          0.100       0.000           0.0  0.836327   0.817308  0.794393
#
#            f1       auc
# 484  0.831354  0.853129
# ...

# %%
pd.read_csv('gridsearch_lstm_end2end.csv').sort_values('f1', ascending=False).head(5)
# Out:
#       epoch  batch_size  embedding_dim  hidden_dim activate_func optimizer  \
# 1217    300         256            300         300          tanh      adam
# 192     200          64            200         200          tanh      adam
# 593     300         128            200         200          relu      adam
# 544     200         128            200         200          tanh      adam
# 87      200          64            200         100          tanh      adam
#
#       learning_rate  l2_regular  dropout_rate  accuracy  precision    recall  \
# 1217          0.001       0.001           0.5  0.830339   0.786667  0.827103
# 192           0.001       0.001           0.5  0.828343   0.785714  0.822430
# 593           0.001       0.001           0.5  0.826347   0.782222  0.822430
# 544           0.001       0.001           0.0  0.826347   0.782222  0.822430
# 87            0.001       0.001           0.5  0.830339   0.805687  0.794393
#
#             f1       auc
# 1217  0.806378  0.829928
# ...
