# %%
import pandas as pd

# %% [markdown]
# # the latest gridsearch results calculated by hpc1

# %%
pd.read_csv('gridsearch_lstm_att_e2e_upsample.csv').sort_values('f1', ascending=False).head(5)
# Out:
#      epoch  batch_size  embedding_dim  hidden_dim activate_func optimizer  \
# 122    300          64            200         200          tanh       sgd
# 53     200          64            200         100          tanh      adam
# 154    300          64            200         300          tanh       sgd
# 54     300          64            200         100          tanh      adam
# 169    200          64            200         300          relu       sgd
#
#      learning_rate  l2_regular  dropout_rate  accuracy  precision    recall  \
# 122          0.100       0.001           0.5  0.962459   0.834320  0.859756
# 53           0.001       0.001           0.5  0.962459   0.859873  0.823171
# 154          0.100       0.001           0.0  0.959514   0.813218  0.862805
# 54           0.001       0.001           0.5  0.958042   0.805714  0.859756
# 169          0.100       0.001           0.0  0.956202   0.796034  0.856707
#
#            f1       auc
# 122  0.846847  0.918158
# ...

# %%
pd.read_csv('gridsearch_lstm_e2e_upsample.csv').sort_values('f1', ascending=False).head(5)
# Out:
#      epoch  batch_size  embedding_dim  hidden_dim activate_func optimizer  \
# 134    250          64            200         300          tanh      adam
# 133    200          64            200         300          tanh      adam
# 28     250          64            200         100          relu       sgd
# 54     250          64            200         100          relu      adam
# 166    250          64            200         300          tanh      adam
#
#      learning_rate  l2_regular  dropout_rate  accuracy  precision    recall  \
# 134          0.001       0.000           0.0  0.960250   0.874150  0.783537
# 133          0.001       0.000           0.0  0.960250   0.874150  0.783537
# 28           0.100       0.001           0.0  0.957306   0.811765  0.841463
# 54           0.001       0.000           0.5  0.960618   0.893238  0.765244
# 166          0.001       0.000           0.5  0.958042   0.856667  0.783537
#
#            f1       auc
# 134  0.826367  0.884024
# ...

# %% [markdown]
# # the latest gridsearch results calculated by hpc7

# %%
pd.read_csv('gridsearch_lstm_attention_end2end.csv').sort_values('f1', ascending=False).head(5)
# Out:
#      epoch  batch_size  embedding_dim  hidden_dim activate_func optimizer  \
# 28     300        64.0          200.0       100.0          relu       sgd
# 252    300        64.0          300.0       100.0          relu       sgd
# 380    300        64.0          300.0       300.0          relu      adam
# 399    200       128.0          200.0       100.0          tanh       sgd
# 1023   200       256.0          300.0       100.0          relu       sgd
#
#       learning_rate  l2_regular  dropout_rate  accuracy  precision    recall  \
# 28            0.100       0.001           0.0  0.964299   0.876221  0.820122
# 252           0.100       0.001           0.5  0.960986   0.832335  0.847561
# 380           0.001       0.000           0.5  0.961722   0.858974  0.817073
# 399           0.100       0.000           0.0  0.960986   0.842593  0.832317
# 1023          0.100       0.000           0.5  0.960250   0.833333  0.838415
#
#             f1       auc
# 28    0.847244  0.902108
# ...

# %%
pd.read_csv('gridsearch_lstm_end2end.csv').sort_values('f1', ascending=False).head(5)
# Out:
#     epoch  batch_size  embedding_dim  hidden_dim activate_func optimizer  \
# 700   300       128.0          300.0       200.0          relu      adam
# 507   200       128.0          200.0       200.0          relu      adam
# 229   200        64.0          300.0       100.0          tanh      adam
# 747   200       128.0          300.0       300.0          tanh      adam
# 508   300       128.0          200.0       200.0          relu      adam
#
#      learning_rate  l2_regular  dropout_rate  accuracy  precision    recall  \
# 700          0.001         0.0           0.5  0.959882   0.863787  0.792683
# 507          0.001         0.0           0.5  0.960250   0.879310  0.777439
# 229          0.001         0.0           0.5  0.960250   0.881944  0.774390
# 747          0.001         0.0           0.5  0.959146   0.855738  0.795732
# 508          0.001         0.0           0.5  0.959882   0.876289  0.777439
#
#            f1       auc
# 700  0.826709  0.887760
# ...

# %% [markdown]
# # the latest gridsearch version calculated by hpc8

# %%
pd.read_csv('gridsearch_lstm_att_w2v_upsample.csv').sort_values('f1', ascending=False).head(5)
# Out:
#                                word2vec  epoch  batch_size  hidden_dim  \
# 181  GoogleNews-vectors-negative300.bin    300          64         300
# 117  GoogleNews-vectors-negative300.bin    300          64         200
# 373  GoogleNews-vectors-negative300.bin    300         128         300
# 500  GoogleNews-vectors-negative300.bin    200         256         200
# 309  GoogleNews-vectors-negative300.bin    300         128         200
#
#     activate_func optimizer  learning_rate  l2_regular  dropout_rate  \
# 181          relu      adam          0.001         0.0           0.5
# 117          relu      adam          0.001         0.0           0.5
# 373          relu      adam          0.001         0.0           0.5
# 500          relu      adam          0.001         0.0           0.5
# 309          relu      adam          0.001         0.0           0.5
#
#      accuracy  precision    recall        f1       auc
# 181  0.966875   0.860606  0.865854  0.863222  0.923299
# ...

# %%
pd.read_csv('gridsearch_lstm_att_w2v.csv').sort_values('f1', ascending=False).head(5)
# Out:
#                                word2vec  epoch  batch_size  hidden_dim  \
# 176  GoogleNews-vectors-negative300.bin    400          64         200
# 174  GoogleNews-vectors-negative300.bin    200          64         200
# 200  GoogleNews-vectors-negative300.bin    400          64         300
# 751  GoogleNews-vectors-negative300.bin    300         256         200
# 438  GoogleNews-vectors-negative300.bin    200         128         200
#
#     activate_func optimizer  learning_rate  l2_regular  dropout_rate  \
# 176          relu      adam          0.001         0.0           0.5
# 174          relu      adam          0.001         0.0           0.5
# 200          tanh      adam          0.001         0.0           0.0
# 751          relu      adam          0.001         0.0           0.5
# 438          tanh      adam          0.001         0.0           0.5
#
#      accuracy  precision    recall        f1       auc
# 176  0.967979   0.857567  0.881098  0.869173  0.930503
# ...

# %%
pd.read_csv('gridsearch_lstm_w2v_upsample.csv').sort_values('f1', ascending=False).head(5)
# Out:
#                                word2vec  epoch  batch_size  hidden_dim  \
# 52   GoogleNews-vectors-negative300.bin    200          64         100
# 181  GoogleNews-vectors-negative300.bin    250          64         300
# 85   GoogleNews-vectors-negative300.bin    250          64         200
# 84   GoogleNews-vectors-negative300.bin    200          64         200
# 53   GoogleNews-vectors-negative300.bin    250          64         100
#
#     activate_func optimizer  learning_rate  l2_regular  dropout_rate  \
# 52           relu      adam          0.001         0.0           0.5
# 181          relu      adam          0.001         0.0           0.5
# 85           relu      adam          0.001         0.0           0.0
# 84           relu      adam          0.001         0.0           0.0
# 53           relu      adam          0.001         0.0           0.5
#
#      accuracy  precision    recall        f1       auc
# 52   0.964667   0.853659  0.853659  0.853659  0.916783
# ...

# %%
pd.read_csv('gridsearch_lstm_w2v.csv').sort_values('f1', ascending=False).head(5)
# Out:
#                                word2vec  epoch  batch_size  hidden_dim  \
# 174  GoogleNews-vectors-negative300.bin    200          64         200
# 78   GoogleNews-vectors-negative300.bin    200          64         100
# 151  GoogleNews-vectors-negative300.bin    300          64         200
# 175  GoogleNews-vectors-negative300.bin    300          64         200
# 248  GoogleNews-vectors-negative300.bin    400          64         300
#
#     activate_func optimizer  learning_rate  l2_regular  dropout_rate  \
# 174          relu      adam          0.001         0.0           0.5
# 78           relu      adam          0.001         0.0           0.5
# 151          tanh      adam          0.001         0.0           0.5
# 175          relu      adam          0.001         0.0           0.5
# 248          tanh      adam          0.001         0.0           0.5
#
#      accuracy  precision    recall        f1       auc
# 174  0.965035   0.847761  0.865854  0.856712  0.922253
# ...
